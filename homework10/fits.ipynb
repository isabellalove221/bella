# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np

# %%
files = [
    "M13_blue_0001.fits",
    "M13_blue_0002.fits",
    "M13_blue_0003.fits",
    "M13_blue_0004.fits",
    "M13_blue_0005.fits"
]
